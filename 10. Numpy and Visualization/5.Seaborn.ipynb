# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
iris=sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.sepal_length
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
sns.scatterplot(x=iris.sepal_length, y=iris.sepal_width)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x=iris.sepal_length, y=iris.petal_length)    # just like scatter in matplotlib
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x=iris.petal_width, y=iris.petal_length)
# Out:
# <Axes: xlabel='petal_width', ylabel='petal_length'>

# %%
sns.displot(iris['sepal_length'])        # just like hist in matplotlib

# %%
sns.histplot(iris['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(iris)         # histogram in seaborn
# Out:
# <Axes: ylabel='Count'>

# %%
sns.pairplot(iris)

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x=tips.total_bill, y=tips.tip)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips['smoker'].value_counts()       # hwo many smokers present here with their catgegory
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.scatterplot(x=tips.total_bill, y=tips.tip, data=tips, hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=tips.total_bill, y=tips.tip,data=tips, hue='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=tips.total_bill, y=tips.tip, data=tips, hue='size', style='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=tips.total_bill, y=tips.tip, data=tips, style='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x=tips.total_bill, y=tips.tip, data=tips,  hue='smoker')

# %%
tips.head()             # starting 5 data
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.relplot(x=tips.total_bill, y=tips.tip, data=tips, hue='size')

# %%
sns.relplot(x=tips.total_bill, y=tips.tip, data=tips, hue='size',style='size')

# %%
sns.relplot(x=tips.total_bill, y=tips.tip, data=tips, style='size')

# %%
sns.replot(x=tips.total_bill, y=tips.tip, data=tips, style='size')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 sns.replot(x=tips.total_bill, y=tips.tip, data=tips, style='size')
#
# AttributeError: module 'seaborn' has no attribute 'replot'

# %%
sns.relplot(x=tips.total_bill, y=tips.tip, data=tips, style='size',hue='time')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, style='size',hue='time')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day', y='total_bill', data=tips)

# %%
sns.barplot(x=tips.day,y=tips.total_bill)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x='smoker', y='tip', data=tips)

# %%
sns.jointplot(x=tips.total_bill, y=tips.tip)       # scatter + histogram

# %%
sns.pairplot(tips)         # plot b/w any numerical everyone vs everyone

# %%
sns.boxplot(tips)
# Out:
# <Axes: >

# %%
sns.violinplot(tips)
# Out:
# <Axes: >

# %%
sns.lineplot(x=tips.total_bill, y=tips.tip)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.kdeplot(tips)   # kernel density estimate (KDE)
# Out:
# <Axes: ylabel='Density'>
