# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: C:\Users\91830\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pd.read_csv("services.csv")     # pandas read the first row as a coloumn name
# Out:
#     Name       "Sex"   "Age"   "Height (in)"   "Weight (lbs)"
# 0   Alex         "M"      41              74              170
# 1   Bert         "M"      42              68              166
# 2   Carl         "M"      32              70              155
# 3   Dave         "M"      39              72              167
# 4   Elly         "F"      30              66              124
# 5   Fran         "F"      33              66              115
# 6   Gwen         "F"      26              64              121
# 7   Hank         "M"      30              71              158
# 8   Ivan         "M"      53              72              175
# 9   Jake         "M"      32              69              143
# 10  Kate         "F"      47              69              139
# 11  Luke         "M"      34              72              163
# 12  Myra         "F"      23              62               98
# 13  Neil         "M"      36              75              160
# ...

# %%
pd.read_csv("services.csv", header=None) # if header=None that data file doesn't have a header row with column names.
# Out:
#        0           1       2               3                4
# 0   Name       "Sex"   "Age"   "Height (in)"   "Weight (lbs)"
# 1   Alex         "M"      41              74              170
# 2   Bert         "M"      42              68              166
# 3   Carl         "M"      32              70              155
# 4   Dave         "M"      39              72              167
# 5   Elly         "F"      30              66              124
# 6   Fran         "F"      33              66              115
# 7   Gwen         "F"      26              64              121
# 8   Hank         "M"      30              71              158
# 9   Ivan         "M"      53              72              175
# 10  Jake         "M"      32              69              143
# 11  Kate         "F"      47              69              139
# 12  Luke         "M"      34              72              163
# 13  Myra         "F"      23              62               98
# ...

# %%
df=pd.read_csv("services.csv")       # services is the csv file that stored this structured data
                                  # pasdas read only structured data
                                # read_csv read complete csv data

# %%
df.head()            # head() read first 5 rows of data
# Out:
#    Name       "Sex"   "Age"   "Height (in)"   "Weight (lbs)"
# 0  Alex         "M"      41              74              170
# 1  Bert         "M"      42              68              166
# 2  Carl         "M"      32              70              155
# 3  Dave         "M"      39              72              167
# 4  Elly         "F"      30              66              124

# %%
df.head(3)     # read first 3 rows
# Out:
#    Name       "Sex"   "Age"   "Height (in)"   "Weight (lbs)"
# 0  Alex         "M"      41              74              170
# 1  Bert         "M"      42              68              166
# 2  Carl         "M"      32              70              155

# %%
df.tail()    # read last 5 rows of data
# Out:
#     Name       "Sex"   "Age"   "Height (in)"   "Weight (lbs)"
# 13  Neil         "M"      36              75              160
# 14  Omar         "M"      38              70              145
# 15  Page         "F"      31              67              135
# 16  Quin         "M"      29              71              176
# 17  Ruth         "F"      28              65              131

# %%
df.tail(3)   # read last 3 rows of data
# Out:
#     Name       "Sex"   "Age"   "Height (in)"   "Weight (lbs)"
# 15  Page         "F"      31              67              135
# 16  Quin         "M"      29              71              176
# 17  Ruth         "F"      28              65              131

# %%
type(df)         # DagaFrame means tabular format
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns           # all the columns name
# Out:
# Index(['Name', '     "Sex"', ' "Age"', ' "Height (in)"', ' "Weight (lbs)"'], dtype='object')

# %%
list(df.columns)      # list of the columns name
# Out:
# ['Name', '     "Sex"', ' "Age"', ' "Height (in)"', ' "Weight (lbs)"']

# %%
df['Name']    # data of a perticular column => Name
# Out:
# 0     Alex
# 1     Bert
# 2     Carl
# 3     Dave
# 4     Elly
# 5     Fran
# 6     Gwen
# 7     Hank
# 8     Ivan
# 9     Jake
# 10    Kate
# 11    Luke
# 12    Myra
# 13    Neil
# 14    Omar
# 15    Page
# 16    Quin
# 17    Ruth
# Name: Name, dtype: object

# %%
df[' "Weight (lbs)"']
# Out:
# 0     170
# 1     166
# 2     155
# 3     167
# 4     124
# 5     115
# 6     121
# 7     158
# 8     175
# 9     143
# 10    139
# 11    163
# 12     98
# 13    160
# 14    145
# 15    135
# 16    176
# 17    131
# Name:  "Weight (lbs)", dtype: int64

# %%
type(df['Name'])     # every single row or column is a series that is equivalent to list
                    # a column----> datatype series
# Out:
# pandas.core.series.Series

# %%
list(df['Name'])
# Out:
# ['Alex',
#  'Bert',
#  'Carl',
#  'Dave',
#  'Elly',
#  'Fran',
#  'Gwen',
#  'Hank',
#  'Ivan',
#  'Jake',
#  'Kate',
#  'Luke',
#  'Myra',
#  'Neil',
#  'Omar',
#  'Page',
#  'Quin',
#  'Ruth']

# %%
df[["Name"]]     # list of a column----> datatype DataFrame
# Out:
#     Name
# 0   Alex
# 1   Bert
# 2   Carl
# 3   Dave
# 4   Elly
# 5   Fran
# 6   Gwen
# 7   Hank
# 8   Ivan
# 9   Jake
# 10  Kate
# 11  Luke
# 12  Myra
# 13  Neil
# 14  Omar
# 15  Page
# 16  Quin
# 17  Ruth

# %%
type(df[["Name"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df[["Name",' "Age"']]     # in the case of multiple column we only pass list
                          # in the case of single column it work without passing list
                          # df["Name",' "Age"']   it gives error
                          # df["Name"] => it works properly
# Out:
#     Name   "Age"
# 0   Alex      41
# 1   Bert      42
# 2   Carl      32
# 3   Dave      39
# 4   Elly      30
# 5   Fran      33
# 6   Gwen      26
# 7   Hank      30
# 8   Ivan      53
# 9   Jake      32
# 10  Kate      47
# 11  Luke      34
# 12  Myra      23
# 13  Neil      36
# 14  Omar      38
# 15  Page      31
# 16  Quin      29
# 17  Ruth      28

# %%
df.dtypes         # it gives the data types of the every column ,,object --> string
# Out:
# Name               object
#      "Sex"         object
#  "Age"              int64
#  "Height (in)"      int64
#  "Weight (lbs)"     int64
# dtype: object

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: C:\Users\91830\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pd.read_excel("exsample.xlsx")
# Out:
#      ID    Months  Unnamed: 2 ListMonths  Unnamed: 4  Unnamed: 5    Unnamed: 6
# 0   1.0   January         NaN    January         NaN         NaN  Select Month
# 1   2.0  February         NaN   February         NaN         NaN        August
# 2   3.0     March         NaN      March         NaN         NaN           NaN
# 3   4.0     April         NaN      April         NaN         NaN           NaN
# 4   NaN       NaN         NaN       June         NaN         NaN           NaN
# 5   5.0      June         NaN       July         NaN         NaN           NaN
# 6   6.0      July         NaN     August         NaN         NaN           NaN
# 7   7.0    August         NaN    October         NaN         NaN           NaN
# 8   NaN       NaN         NaN   December         NaN         NaN           NaN
# 9   8.0   October         NaN        NaN         NaN         NaN           NaN
# 10  NaN       NaN         NaN        NaN         NaN         NaN           NaN
# ...

# %%
df1=pd.read_excel("exsample.xlsx")

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# ID            float64
# Months         object
# Unnamed: 2    float64
# ListMonths     object
# Unnamed: 4    float64
# Unnamed: 5    float64
# Unnamed: 6     object
# dtype: object

# %%
df1.columns
# Out:
# Index(['ID', 'Months', 'Unnamed: 2', 'ListMonths', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6'],
#       dtype='object')

# %%
df1["ID"]
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     NaN
# 5     5.0
# 6     6.0
# 7     7.0
# 8     NaN
# 9     8.0
# 10    NaN
# 11    9.0
# Name: ID, dtype: float64

# %%
df1[['Months','Unnamed: 2', 'ListMonths']]
# Out:
#       Months  Unnamed: 2 ListMonths
# 0    January         NaN    January
# 1   February         NaN   February
# 2      March         NaN      March
# 3      April         NaN      April
# 4        NaN         NaN       June
# 5       June         NaN       July
# 6       July         NaN     August
# 7     August         NaN    October
# 8        NaN         NaN   December
# 9    October         NaN        NaN
# 10       NaN         NaN        NaN
# 11  December         NaN        NaN

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")    # it is a link that contain this csv type data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
type(df2["Survived"])
# Out:
# pandas.core.series.Series

# %%
df2[["Survived","Parch"]]
# Out:
#      Survived  Parch
# 0           0      0
# 1           1      0
# 2           1      0
# 3           1      0
# 4           0      0
# ..        ...    ...
# 886         0      0
# 887         1      0
# 888         0      2
# 889         1      0
# 890         0      0
#
# [891 rows x 2 columns]

# %%
df2.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
import pandas as pd
url_data=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: C:\Users\91830\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
url_data    # it return list
            #it read only structured /tabular data on a html page
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
df3=url_data[0]

# %%
df3
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df3.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df3.tail(4)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 671  170  245  135  86  17  75  115  685
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [4 rows x 30 columns]

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df3["Rk"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 670    490
# 671    490
# 672    490
# 673    491
# 674    492
# Name: Rk, Length: 675, dtype: object

# %%
df3[['Player', 'Pos', 'Age']]
# Out:
#              Player Pos Age
# 0        Quincy Acy  PF  24
# 1      Jordan Adams  SG  20
# 2      Steven Adams   C  21
# 3       Jeff Adrien  PF  28
# 4     Arron Afflalo  SG  29
# ..              ...  ..  ..
# 670  Thaddeus Young  PF  26
# 671  Thaddeus Young  PF  26
# 672  Thaddeus Young  PF  26
# 673     Cody Zeller   C  22
# 674    Tyler Zeller   C  25
#
# [675 rows x 3 columns]

# %%
df3.to_csv("player_data.csv")      # for save/store the data in a another file(local system)
                                   # raw data index considered by default

# %%
df3.to_csv("player_data_dup.csv",index=False)    # raw data index not considered
