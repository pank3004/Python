# %% [markdown]
# #### use mydb.commit() after insert data and use cursor.fetchall() after query see the data

# %%
pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
# ...

# %%
pip install mysql
# Out:
# ...
#    ---------------------------------------- 0.0/203.2 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/203.2 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/203.2 kB ? eta -:--:--
#    ----- --------------------------------- 30.7/203.2 kB 217.9 kB/s eta 0:00:01
#    ------- ------------------------------- 41.0/203.2 kB 245.8 kB/s eta 0:00:01
#    ----------- --------------------------- 61.4/203.2 kB 272.3 kB/s eta 0:00:01
#    ------------- ------------------------- 71.7/203.2 kB 261.4 kB/s eta 0:00:01
#    ------------------- ------------------ 102.4/203.2 kB 310.3 kB/s eta 0:00:01
#    ---------------------- --------------- 122.9/203.2 kB 343.4 kB/s eta 0:00:01
#    ---------------------- --------------- 122.9/203.2 kB 343.4 kB/s eta 0:00:01
#    ---------------------------- --------- 153.6/203.2 kB 353.1 kB/s eta 0:00:01
#    ---------------------------- --------- 153.6/203.2 kB 353.1 kB/s eta 0:00:01
# ...

# %%
import mysql.connector as conn

# %%
mydb=conn.connect(host='localhost', user='root', passwd='Pankajsql@123')

# %%
mydb

# %%
cursor=mydb.cursor()

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('college',),
#  ('information_schema',),
#  ('mysql',),
#  ('pankaj',),
#  ('performance_schema',),
#  ('pw',),
#  ('pwioi',),
#  ('sakila',),
#  ('sys',),
#  ('windowfun',),
#  ('world',)]

# %%
cursor.execute('create database pysqldb')

# %%
cursor.execute('show databases')
cursor.fetchall()
# Out:
# [('college',),
#  ('information_schema',),
#  ('mysql',),
#  ('pankaj',),
#  ('performance_schema',),
#  ('pw',),
#  ('pwioi',),
#  ('pysqldb',),
#  ('sakila',),
#  ('sys',),
#  ('windowfun',),
#  ('world',)]

# %%
cursor.execute('create table if not exists pysqldb.pwskills(student_id int(10), first_name varchar(20), last_name varchar(30), reg_id int(10), class_name varchar(30))')

# %%
cursor.execute('use pysqldb')

# %%
cursor.execute('show tables')
cursor.fetchall()
# Out:
# [('pwskills',)]

# %%
cursor.execute("insert into pysqldb.pwskills values(24, 'panakj', 'kumawat', 101, 'data science')")
mydb.commit()

# %%
cursor.execute('select * from pysqldb.pwskills')
cursor.fetchall()
# Out:
# [(24, 'panakj', 'kumawat', 101, 'data science')]

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is BE55-3760
#
#  Directory of c:\Users\91830\Python\7 Conneting sql to python
#
# 04/11/2024  09:26 AM    <DIR>          .
# 04/10/2024  08:35 PM    <DIR>          ..
# 04/11/2024  09:22 AM           144,545 1_connect_mysql.ipynb
# 04/11/2024  09:21 AM            11,903 glass.data
#                2 File(s)        156,448 bytes
#                2 Dir(s)  416,985,559,040 bytes free

# %%
import csv 
with open('glass.data', 'r') as f: 
    glass_data=csv.reader(f, delimiter='\n')
    for i in glass_data: 
        print(i[0])
# Out:
# 1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1
# 2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1
# 3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1
# 4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1
# 5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1
# 6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1
# 7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1
# 8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1
# 9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1
# 10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1
# 11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1
# 12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1
# 13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1
# 14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1
# 15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1
# 16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1
# 17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1
# ...

# %%
cursor.execute('create table pysqldb.glassdata(col1 INT(10) ,col2 float(10,5),col3 float(10,5) ,col4 float(10,5) , col5 float(10,5),col6 float(10,5) ,clo7 float(10,5) , col8 float(10,5) , col9 float(10,5) , col10 float(10,5) , col11 INT(10)) ')

# %%
with open('glass.data', 'r') as f: 
    glass_data=csv.reader(f, delimiter='\n')
    for i in glass_data: 
        print(type(i[0]))
        print(f'insert into glassdata values ({str(i[0])})')
        cursor.execute('insert into pysqldb.glassdata values({values})'.format(values=((i[0]))))

        
        mydb.commit()
# Out:
# <class 'str'>
# insert into glassdata values (1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1)
# <class 'str'>
# insert into glassdata values (7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1)
# <class 'str'>
# ...

# %%
cursor.execute('select * from pysqldb.glassdata')
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.0 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.0 kB ? eta -:--:--
#      -------------------------------------- 61.0/61.0 kB 651.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB 1.3 MB/s eta 0:00:10
#    ---------------------------------------- 0.1/11.6 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/11.6 MB 901.1 kB/s eta 0:00:13
#     --------------------------------------- 0.3/11.6 MB 1.2 MB/s eta 0:00:10
#     --------------------------------------- 0.3/11.6 MB 1.2 MB/s eta 0:00:10
# ...

# %%
import pandas as pd

# %%
pd.read_sql('select * from pysqldb.glassdata', mydb)
# Out:
# C:\Users\91830\AppData\Local\Temp\ipykernel_13404\1736149595.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('select * from pysqldb.glassdata', mydb)
#      col1     col2   col3  col4  col5   col6  clo7  col8  col9  col10  col11
# 0       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00    0.0      1
# 1       2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.0      1
# 2       3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.0      1
# 3       4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.0      1
# 4       5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.0      1
# ..    ...      ...    ...   ...   ...    ...   ...   ...   ...    ...    ...
# 209   210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.0      7
# ...

# %%
pd.read_sql('show databases', mydb)
# Out:
# C:\Users\91830\AppData\Local\Temp\ipykernel_13404\3468230276.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('show databases', mydb)
#               Database
# 0              college
# 1   information_schema
# 2                mysql
# 3               pankaj
# 4   performance_schema
# 5                   pw
# 6                pwioi
# 7              pysqldb
# 8               sakila
# 9                  sys
# 10           windowfun
# 11               world
